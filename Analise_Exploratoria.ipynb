# %%
#importando as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
#upload do arquivo
from google.colab import files
arq = files.upload()
# Out:
#      <input type="file" id="files-cb26d885-879f-481b-b0a9-b28baf205fa3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cb26d885-879f-481b-b0a9-b28baf205fa3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AdventureWorks.xlsx to AdventureWorks.xlsx

# %%
#lendo o arquivo excel
df = pd.read_excel("AdventureWorks.xlsx")

# %%
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ...            Marca   Classe  Cor
# 0 2008-05-09 2008-05-29      199  ...  Adventure Works  Regular  Red
# 1 2008-05-12 2008-05-17      306  ...  Adventure Works  Regular  Red
# 2 2008-05-14 2008-05-20      306  ...  Adventure Works  Regular  Red
# 3 2008-05-21 2008-05-27      306  ...  Adventure Works  Regular  Red
# 4 2008-06-20 2008-06-27      306  ...  Adventure Works  Regular  Red
#
# [5 rows x 16 columns]

# %%
#retorna a quantidade de linhas e colunas
df.shape
# Out:
# (904, 16)

# %%
#retorna os tipos de cada coluna
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
#retorna a receita total
df['Valor Venda'].sum()
# Out:
# 5984606.1426

# %%
#retornar o custo total
custo = df['Custo Unitário'] * df['Quantidade']
custo.sum()
# Out:
# 2486783.05

# %%
#criar a coluna custo total
df['Custo_Total'] = df['Custo Unitário'] * df['Quantidade']

# %%
df.sample(5)
# Out:
#     Data Venda Data Envio  ID Loja  ...   Classe     Cor Custo_Total
# 755 2008-08-09 2008-08-13      199  ...  Economy   White      732.96
# 748 2009-10-12 2009-10-21      306  ...  Economy   White      977.28
# 716 2009-03-18 2009-03-30      307  ...  Economy  Silver     1099.44
# 760 2008-11-10 2008-11-19      199  ...  Economy   White     1588.08
# 86  2009-09-21 2009-09-30      307  ...  Regular    Grey     1948.14
#
# [5 rows x 17 columns]

# %%
#criando uma coluna de lucro
df['Lucro'] = df['Valor Venda'] - df['Custo_Total']
df.sample(5)
# Out:
#     Data Venda Data Envio  ID Loja  ...    Cor  Custo_Total     Lucro
# 762 2008-12-03 2008-12-10      199  ...  White       794.04   452.712
# 333 2008-11-27 2008-12-10      307  ...    Red      3137.22  2661.480
# 642 2008-02-07 2008-02-20      199  ...  White      1653.30  3087.200
# 839 2008-12-14 2008-12-19      307  ...   Grey      1948.14  3049.860
# 422 2009-10-21 2009-10-30      306  ...  Black      2922.21  4133.790
#
# [5 rows x 18 columns]

# %%
#arredondar a coluna lucro
df['Lucro'] = round(df['Lucro'],2)

# %%
df.sample(5)
# Out:
#     Data Venda Data Envio  ID Loja  ...    Cor  Custo_Total    Lucro
# 327 2008-03-07 2008-03-16      199  ...    Red      2440.06  2600.64
# 781 2008-06-10 2008-06-14      307  ...  White       732.96   561.74
# 651 2009-11-13 2009-11-23      306  ...  White      1653.30  2338.70
# 516 2009-03-13 2009-03-25      307  ...  Black      3485.80  2578.20
# 870 2009-12-20 2009-12-25      199  ...  Black      2091.48  1546.92
#
# [5 rows x 18 columns]

# %%
#retorna o lucro total de todas as vendas
df['Lucro'].sum()
# Out:
# 3497823.0

# %%
#criando coluna tempo de envio
df['Tempo_Envio'] = (df['Data Envio'] - df['Data Venda']).dt.days

# %%
df.sample(3)
# Out:
#     Data Venda Data Envio  ID Loja  ...  Custo_Total    Lucro Tempo_Envio
# 225 2009-07-16 2009-07-29      307  ...      2788.64  3275.36          13
# 846 2008-02-08 2008-02-19      306  ...      1948.14  3520.26          11
# 76  2009-04-03 2009-04-15      199  ...      1983.96  4004.04          12
#
# [3 rows x 19 columns]

# %%
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# Custo_Total              float64
# Lucro                    float64
# Tempo_Envio                int64
# dtype: object

# %%
#retornar a média do tempo de envio por marca
df.groupby('Marca')['Tempo_Envio'].mean()
# Out:
# Marca
# Adventure Works    8.663866
# Contoso            8.470930
# Fabrikam           8.510121
# Name: Tempo_Envio, dtype: float64

# %%
#verificando se temos valores ausentes
df.isnull().sum()
# Out:
# Data Venda        0
# Data Envio        0
# ID Loja           0
# ID Produto        0
# ID Cliente        0
# No. Venda         0
# Custo Unitário    0
# Preço Unitário    0
# Quantidade        0
# Valor Desconto    0
# Valor Venda       0
# Produto           0
# Fabricante        0
# Marca             0
# Classe            0
# Cor               0
# Custo_Total       0
# Lucro             0
# Tempo_Envio       0
# dtype: int64

# %%
#salvar o arquivo em csv
df.to_csv("df_vendas_novo.csv", index=False)
